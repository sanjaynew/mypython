# %%
import pandas as pd

# %%
df=pd.read_csv("C:\\Users\\91921\\Desktop\\csv\\Weather Data.csv")

# %%
df.head
# Out:
# <bound method NDFrame.head of              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
df.head(5)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
# 3  1/1/2012 3:00    -1.5              -3.2         88                6
# 4  1/1/2012 4:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
df.shape
# Out:
# (8784, 8)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=8784, step=1)

# %%
df.columns
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Date/Time            object
# Temp_C              float64
# Dew Point Temp_C    float64
# Rel Hum_%             int64
# Wind Speed_km/h       int64
# Visibility_km       float64
# Press_kPa           float64
# Weather              object
# dtype: object

# %%
df.unique
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-24917de15bc0> in <module>
# ----> 1 df.unique
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'unique'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date/Time         8784 non-null   object
#  1   Temp_C            8784 non-null   float64
#  2   Dew Point Temp_C  8784 non-null   float64
#  3   Rel Hum_%         8784 non-null   int64
#  4   Wind Speed_km/h   8784 non-null   int64
#  5   Visibility_km     8784 non-null   float64
#  6   Press_kPa         8784 non-null   float64
#  7   Weather           8784 non-null   object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 549.1+ KB

# %%
df.head(2)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather
# 0            8.0     101.24     Fog
# 1            8.0     101.24     Fog

# %% [markdown]
# # Find all the unique 'Wind Speed' values in the data.

# %%
df['Wind Speed_km/h'].unique() #Find all the unique 'Wind Speed' values in the data. .
# Out:
# array([ 4,  7,  6,  9, 15, 13, 20, 22, 19, 24, 30, 35, 39, 32, 33, 26, 44,
#        43, 48, 37, 28, 17, 11,  0, 83, 70, 57, 46, 41, 52, 50, 63, 54,  2],
#       dtype=int64)

# %%
df['Wind Speed_km/h'].nunique() #Find all the nunique 'Wind Speed' values in the data. .
# Out:
# 34

# %%
df.Weather=='clear'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8779    False
# 8780    False
# 8781    False
# 8782    False
# 8783    False
# Name: Weather, Length: 8784, dtype: bool

# %%
df[df.Weather == 'clear']
# Out:
# Empty DataFrame
# Columns: [Date/Time, Temp_C, Dew Point Temp_C, Rel Hum_%, Wind Speed_km/h, Visibility_km, Press_kPa, Weather]
# Index: []

# %% [markdown]
# # Q. 2) Find the number of times when the 'Weather is exactly Clear'.
# use filter,groupby,value_counts()

# %%
df.Weather.value_counts()
# Out:
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Haze                                         16
# Thunderstorms,Rain Showers                   16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# Freezing Drizzle,Snow                        11
# ...

# %%
df.Weather.value_counts()['Clear'] # show exact value count of specfc Term in Weather column
# Out:
# 1326

# %%
df.Weather.value_counts(normalize=True)# show value in persentage
# Out:
# Mainly Clear                               0.239754
# Mostly Cloudy                              0.235542
# Cloudy                                     0.196721
# Clear                                      0.150956
# Snow                                       0.044399
# Rain                                       0.034836
# Rain Showers                               0.021403
# Fog                                        0.017077
# Rain,Fog                                   0.013206
# Drizzle,Fog                                0.009107
# Snow Showers                               0.006831
# Drizzle                                    0.004668
# Snow,Fog                                   0.004212
# Snow,Blowing Snow                          0.002163
# Rain,Snow                                  0.002049
# Haze                                       0.001821
# Thunderstorms,Rain Showers                 0.001821
# Drizzle,Snow,Fog                           0.001708
# ...

# %%
df.head(2)

# %%
df

# %%
df.Weather=='Clear'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8779    False
# 8780    False
# 8781    False
# 8782    False
# 8783    False
# Name: Weather, Length: 8784, dtype: bool

# %%
df.Weather=='Clear'# gives result in boolean
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8779    False
# 8780    False
# 8781    False
# 8782    False
# 8783    False
# Name: Weather, Length: 8784, dtype: bool

# %%
df[df.Weather=='Clear'] # gives result in values
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67      1/3/2012 19:00   -16.9             -24.8         50               24
# 114     1/5/2012 18:00    -7.1             -14.4         56               11
# 115     1/5/2012 19:00    -9.2             -15.4         61                7
# 116     1/5/2012 20:00    -9.8             -15.7         62                9
# 117     1/5/2012 21:00    -9.0             -14.8         63               13
# ...                ...     ...               ...        ...              ...
# 8646   12/26/2012 6:00   -13.4             -14.8         89                4
# 8698  12/28/2012 10:00    -6.1              -8.6         82               19
# 8713   12/29/2012 1:00   -11.9             -13.6         87               11
# 8714   12/29/2012 2:00   -11.8             -13.1         90               13
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
#       Visibility_km  Press_kPa Weather
# ...

# %%
df.describe()
# Out:
#             Temp_C  Dew Point Temp_C    Rel Hum_%  Wind Speed_km/h  \
# count  8784.000000       8784.000000  8784.000000      8784.000000
# mean      8.798144          2.555294    67.431694        14.945469
# std      11.687883         10.883072    16.918881         8.688696
# min     -23.300000        -28.500000    18.000000         0.000000
# 25%       0.100000         -5.900000    56.000000         9.000000
# 50%       9.300000          3.300000    68.000000        13.000000
# 75%      18.800000         11.800000    81.000000        20.000000
# max      33.000000         24.400000   100.000000        83.000000
#
#        Visibility_km    Press_kPa
# count    8784.000000  8784.000000
# mean       27.664447   101.051623
# std        12.622688     0.844005
# min         0.200000    97.520000
# 25%        24.100000   100.560000
# 50%        25.000000   101.070000
# 75%        25.000000   101.590000
# max        48.300000   103.650000

# %%
df1=df.groupby('Weather') # groupby group the column string value into alphabetic order

# %%
df1.head(100)
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8741   12/30/2012 5:00    -9.1             -10.4         90               11
# 8742   12/30/2012 6:00    -9.3             -10.8         89               17
# 8767   12/31/2012 7:00    -9.3             -11.3         85                0
# 8768   12/31/2012 8:00    -8.6             -10.3         87                4
# 8770  12/31/2012 10:00    -7.4              -8.9         89                4
#
# ...

# %%
df.groupby('Weather').get_group('Clear')# get_group to find the exect match

# %%
df

# %% [markdown]
# # Find the number of times when the 'Wind Speed was exactly 4 km/h'

# %%
df.head(2)

# %%
df[df["Wind Speed_km/h"] == 4]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 96       1/5/2012 0:00    -8.8             -11.7         79                4
# 101      1/5/2012 5:00    -7.0              -9.5         82                4
# 146      1/7/2012 2:00    -8.1             -11.1         79                4
# ...                ...     ...               ...        ...              ...
# 8768   12/31/2012 8:00    -8.6             -10.3         87                4
# 8769   12/31/2012 9:00    -8.1              -9.6         89                4
# 8770  12/31/2012 10:00    -7.4              -8.9         89                4
# 8772  12/31/2012 12:00    -5.8              -7.5         88                4
# 8773  12/31/2012 13:00    -4.6              -6.6         86                4
#
#       Visibility_km  Press_kPa       Weather
# ...

# %% [markdown]
# # Find out all the Null Values in the data

# %%
df.isnull() #showing boolean

# %%
df.isnull().sum() # showing all null value which is not any null

# %%
df.notnull().sum()# not null value

# %% [markdown]
# # Rename the column name 'Weather' of the dataframe to 'Weather Condition'.

# %%
df.rename(columns={'Weather':'Weather condition'})# rename function is temperory rename

# %%
df

# %%
df1=df.rename(columns={'Weather':'Weather condition'},inplace=True) # chande name parmanently using inplace=True

# %%
df1

# %%
df1.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-83941e9879da> in <module>
# ----> 1 df1.info()
#
# NameError: name 'df1' is not defined

# %% [markdown]
# For Selecting The Data
# 1. df[[‘Col1’, ‘Col2’ , ‘Col3’ ]] # Selecting multiple Columns from the DF.
# 2. df.loc[ : , ‘Col1’ : ‘Col2’] # Selecting columns with object slicing.
# 3. df.iloc[ : , 1:4 ] # Selecting columns with integer slicing.

# %%
df.head(2)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather
# 0            8.0     101.24     Fog
# 1            8.0     101.24     Fog

# %%
df[['Date/Time','Temp_C','Weather']]
# Out:
#              Date/Time  Temp_C               Weather
# 0        1/1/2012 0:00    -1.8                   Fog
# 1        1/1/2012 1:00    -1.8                   Fog
# 2        1/1/2012 2:00    -1.8  Freezing Drizzle,Fog
# 3        1/1/2012 3:00    -1.5  Freezing Drizzle,Fog
# 4        1/1/2012 4:00    -1.5                   Fog
# ...                ...     ...                   ...
# 8779  12/31/2012 19:00     0.1                  Snow
# 8780  12/31/2012 20:00     0.2                  Snow
# 8781  12/31/2012 21:00    -0.5                  Snow
# 8782  12/31/2012 22:00    -0.2                  Snow
# 8783  12/31/2012 23:00     0.0                  Snow
#
# [8784 rows x 3 columns]

# %%
df[['Date/Time','Temp_C','Weather']].head(5)
# Out:
#        Date/Time  Temp_C               Weather
# 0  1/1/2012 0:00    -1.8                   Fog
# 1  1/1/2012 1:00    -1.8                   Fog
# 2  1/1/2012 2:00    -1.8  Freezing Drizzle,Fog
# 3  1/1/2012 3:00    -1.5  Freezing Drizzle,Fog
# 4  1/1/2012 4:00    -1.5                   Fog

# %%
df.loc[ : ,'Date/Time':'Visibility_km']
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
#       Visibility_km
# 0               8.0
# ...

# %%
df.iloc[ : ,1 : 4]
# Out:
#       Temp_C  Dew Point Temp_C  Rel Hum_%
# 0       -1.8              -3.9         86
# 1       -1.8              -3.7         87
# 2       -1.8              -3.4         89
# 3       -1.5              -3.2         88
# 4       -1.5              -3.3         88
# ...      ...               ...        ...
# 8779     0.1              -2.7         81
# 8780     0.2              -2.4         83
# 8781    -0.5              -1.5         93
# 8782    -0.2              -1.8         89
# 8783     0.0              -2.1         86
#
# [8784 rows x 3 columns]
